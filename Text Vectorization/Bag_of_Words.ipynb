# %%
import pandas as pd
data={
    "text":["people watch youtube","youtube watch youtube","people write comment","youtube write comment"],
    "num":[10,20,30,40],
    
}
df=pd.DataFrame(data)
print(df)
# Out:
#                     text  num
# 0   people watch youtube   10
# 1  youtube watch youtube   20
# 2   people write comment   30
# 3  youtube write comment   40

# %%
from sklearn.feature_extraction.text import CountVectorizer

cv=CountVectorizer()

count_vectorizer=cv.fit_transform(df['text'])

# %%
print(cv.vocabulary_)
# Out:
# {'people': 1, 'watch': 2, 'youtube': 4, 'write': 3, 'comment': 0}

# %%
print(count_vectorizer[0].toarray())
print(count_vectorizer[1].toarray())
print(count_vectorizer[2].toarray())
print(count_vectorizer[3].toarray())
# Out:
# [[0 1 1 0 1]]
# [[0 0 1 0 2]]
# [[1 1 0 1 0]]
# [[1 0 0 1 1]]

# %%
cv.transform(["youtube people watch and write"]).toarray()
#and not mentioned
# Out:
# array([[0, 1, 1, 1, 1]])
