# %%
#Game of Thronses
import numpy as np
import pandas as pd

# %%
import gensim
import os

# %%
from nltk import sent_tokenize
from gensim.utils import simple_preprocess

story=[]
for filename in os.listdir('data'):
    f=open(os.path.join('data',filename))
    corpus=f.read()
    raw_sent=sent_tokenize(corpus)
    for sent in raw_sent:
        story.append(simple_preprocess(sent))

# %%
print(len(story))
# Out:
# 145020

# %%
model=gensim.models.Word2Vec(
    window=10,
    min_count=2
)
#window=>window size 10

# %%
model.build_vocab(story)

# %%
model.train(story,total_examples=model.corpus_count,epochs=model.epochs)
# Out:
# (6569496, 8628190)

# %%
model.wv.most_similar('daenerys')
# Out:
# [('stormborn', 0.7849172353744507),
#  ('princess', 0.7422652840614319),
#  ('targaryen', 0.708121120929718),
#  ('myrcella', 0.7078933119773865),
#  ('elia', 0.691373884677887),
#  ('unburnt', 0.691045880317688),
#  ('queen', 0.6792742609977722),
#  ('dorne', 0.6731647849082947),
#  ('rhaegar', 0.6716859936714172),
#  ('margaery', 0.668499231338501)]

# %%
model.wv.most_similar('game')
# Out:
# [('dusting', 0.6740877628326416),
#  ('details', 0.6593464612960815),
#  ('enemy', 0.6556485295295715),
#  ('smugglers', 0.6434875726699829),
#  ('farce', 0.6427472829818726),
#  ('trouble', 0.6406198143959045),
#  ('enmities', 0.6321688294410706),
#  ('villages', 0.6268926858901978),
#  ('distinction', 0.6206244826316833),
#  ('ways', 0.6205006837844849)]

# %%
model.wv.most_similar('king')
# Out:
# [('baratheon', 0.6885104775428772),
#  ('prince', 0.6668648719787598),
#  ('realm', 0.6608996391296387),
#  ('throne', 0.6391465067863464),
#  ('targaryen', 0.6328579783439636),
#  ('tourney', 0.6087694764137268),
#  ('conqueror', 0.598313570022583),
#  ('dorne', 0.5905212759971619),
#  ('victory', 0.5844075679779053),
#  ('dragonstone', 0.5761975049972534)]

# %%
model.wv.most_similar('dead')
# Out:
# [('dying', 0.6574276685714722),
#  ('alone', 0.5641753673553467),
#  ('wolf', 0.5546224117279053),
#  ('now', 0.5320172905921936),
#  ('talking', 0.5187495946884155),
#  ('living', 0.49527162313461304),
#  ('rangings', 0.48317381739616394),
#  ('dreams', 0.47941747307777405),
#  ('coming', 0.47541531920433044),
#  ('still', 0.47186335921287537)]

# %%
#document to vector using word vectors
# def document_to_vector(doc):
#     doc=[word for word in doc.split() if word in model.wv.index_to_key]
#     return np.mean(model.wv[doc],axis=0)

# %%
#to convert all documents to vector in dataset
# from tqdm import tqdm
# X=[]
# for doc in tqdm(df['text'].values):
#     x.append(document_to_vector(doc))

# X=np.array(X)
